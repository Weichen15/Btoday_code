# %% [markdown]
# ### 資料整理流程
#
# #### GA4報表後台資料：
# df_article (df_article_bk)
#
# #### GA4平台資料：
# df_ga (df_ga_bk)
#
# #### 合併資料：
# df_data_all
#
#
# 一、資料前處理
#
#     1. df_article
#         資料來源：GA4後台資料。已經將過去一年資料作合併，如果有重複id的部分也已經做處理
#         [1] 修改欄位命名
#             (1) "文章ID" -> "article_id"
#             (2) "瀏覽量_Sum" -> "PV_sum"
#         [2] 文章母分類、文章子分類，留下第一筆
#             "bt_main_category", "bt_sub_category"
#         [3] df_article.colums：['article_id', 'PV_sum', '文章標題', '文章來源', '文章屬性', '名人專區', '撰文', 'SEO分類', '文章字數', '上稿者', '最後修改者', '文章發布', 'bt_main_categroy', 'bt_sub_categroy']
#
#     2. df_ga
#         資料來源：從GA4平台下載資料，依據所需的來源媒介下載，例如：google/organic、FB/article等
#
#         [1] 移除null值：將 "Page path" 或者 "Views" 為空值的資料移除
#         [2] 去除Views為0的資料：瀏覽是0的話就不紀錄
#         [3] Page path 結尾不是 "/" 的資料：一般文章的Page path為 /article/.../20XXXXXXXX/
#         [4] 合併重複article_id瀏覽量 (df_ga_sum)
#
#     3. df_data_all
#         pd.merge(df_ga_sum, df_article)
#
#         [1] 部分只有圖片的文章，字數為NaN，填入0。
#         [2] article_id前八碼為YYYYMMDD，新增欄位"article_date"，來記錄真實文章產出時間。
#
# 二、EDA
#
#     1. 依文章屬性檢視
#     2. 新文章及舊文章比較

# %%
import numpy as np
import pandas as pd
import re

import matplotlib.pyplot as plt
import seaborn as sns
sns.set() 
## We'll code the graphs using 'matplotlib' but they'll be displayed with the 'seaborn' look

# %matplotlib inline 
# ## 可內嵌繪圖，並且可省略 plt.show()這個指令

# %% [markdown]
# # 1. 資料前處裡

# %% [markdown]
# ## 後台資料

# %%
df_article = pd.read_csv("../ALL_Data/GA4_ALL_DATA.csv")

df_article_bk1 = df_article.copy()

df_article.head()
# Out:
#            文章ID  瀏覽量_Sum                                              文章標題  \
# 0  202305250031  1835894             明年過年放7天！2024年行事曆公布…3天以上連續假期有4個「開始排休囉」
# 1  202309020003   935926       全台停班停課一覽》海葵何時最接近、基北北桃放不放颱風假？哪天風雨最大？一圖看懂影響時程
# 2  202208240059   719167         台大法律系高材生頂撞賣臭豆腐的父母：阿母的沉默讓我羞愧「以為辯贏了，其實輸得徹底」
# 3  202306200007   636319    黃子佼當年最愛她》5歲出道、曾月刷20萬險變卡奴，30歲存千萬買房孝親！48歲蔡燦得的致富術
# 4  202312050037   609553  「太太輕生掛在16樓高空」前科技部長陳良基辭官退休，陪妻度過憂鬱症：結婚發誓照顧到老，說話要算數
#
#                 文章來源  文章屬性  名人專區           撰文 今周文章母分類 今周文章子分類 ESG文章母分類  \
# 0              數位部記者  政治社會   NaN        李易紓整理    產業時事    政治社會      NaN
# 1              數位部記者  生活消費   NaN       黃明惠 整理    職場生活    生活消費      NaN
# 2  外稿/書摘/廣編（無稿費不可轉載)  家庭教育  精選書摘          許峰源    職場生活    情感關係      NaN
# 3  外稿/書摘/廣編（無稿費不可轉載)  投資理財  各家之言  女人我最大 / 池宗玲    投資理財      理財      NaN
# 4  外稿/書摘/廣編（無稿費不可轉載)  職場學習  精選書摘    王素梅, 陳良基     職場生活    情感關係      NaN
#
#   ESG文章子分類  熟齡文章母分類    熟齡文章子分類                                   SEO分類  \
# 0      NaN      NaN        NaN          人事行政總處/2024年行事曆/113年行事曆/過年7天年假
# 1      NaN      NaN        NaN  海葵颱風/颱風假/颱風路徑/最新颱風動態/颱風會來嗎/海葵颱風動向/停班停課
# 2      NaN  靚女學/靚女學  家庭關係/自我成長                      台大/孝順/頂嘴/資優生/父母/教育
# 3      NaN      NaN        NaN                     黃子佼/蔡燦得/買房/記帳/理財/退休
# 4      NaN      NaN        NaN              陳良基/憂鬱症/王素梅/陳良基 老婆/陳良基 憂鬱症
#
#      文章字數  上稿者 最後修改者        文章發布
# 0  1324.0  李易紓   李易紓  2023-06-20
# 1  3562.0  黃明惠   李易紓  2023-09-04
# 2  2485.0  洪慧如   郭美懿  2022-11-16
# 3  1151.0  洪慧如   李易紓  2023-06-20
# 4  2944.0  洪慧如   洪慧如  2023-12-05

# %%
df_article.columns
# Out:
# Index(['文章ID', '瀏覽量_Sum', '文章標題', '文章來源', '文章屬性', '名人專區', '撰文', '今周文章母分類',
#        '今周文章子分類', 'ESG文章母分類', 'ESG文章子分類', '熟齡文章母分類', '熟齡文章子分類', 'SEO分類',
#        '文章字數', '上稿者', '最後修改者', '文章發布'],
#       dtype='object')

# %% [markdown]
# ### Rename 文章ID 為 article_id，後面作為合併欄位

# %%
df_article.rename(columns={"文章ID": "article_id", "瀏覽量_Sum": "PV_sum"}, inplace=True)

df_article.head()
# Out:
#      article_id   PV_sum                                              文章標題  \
# 0  202305250031  1835894             明年過年放7天！2024年行事曆公布…3天以上連續假期有4個「開始排休囉」
# 1  202309020003   935926       全台停班停課一覽》海葵何時最接近、基北北桃放不放颱風假？哪天風雨最大？一圖看懂影響時程
# 2  202208240059   719167         台大法律系高材生頂撞賣臭豆腐的父母：阿母的沉默讓我羞愧「以為辯贏了，其實輸得徹底」
# 3  202306200007   636319    黃子佼當年最愛她》5歲出道、曾月刷20萬險變卡奴，30歲存千萬買房孝親！48歲蔡燦得的致富術
# 4  202312050037   609553  「太太輕生掛在16樓高空」前科技部長陳良基辭官退休，陪妻度過憂鬱症：結婚發誓照顧到老，說話要算數
#
#                 文章來源  文章屬性  名人專區           撰文 今周文章母分類 今周文章子分類 ESG文章母分類  \
# 0              數位部記者  政治社會   NaN        李易紓整理    產業時事    政治社會      NaN
# 1              數位部記者  生活消費   NaN       黃明惠 整理    職場生活    生活消費      NaN
# 2  外稿/書摘/廣編（無稿費不可轉載)  家庭教育  精選書摘          許峰源    職場生活    情感關係      NaN
# 3  外稿/書摘/廣編（無稿費不可轉載)  投資理財  各家之言  女人我最大 / 池宗玲    投資理財      理財      NaN
# 4  外稿/書摘/廣編（無稿費不可轉載)  職場學習  精選書摘    王素梅, 陳良基     職場生活    情感關係      NaN
#
#   ESG文章子分類  熟齡文章母分類    熟齡文章子分類                                   SEO分類  \
# 0      NaN      NaN        NaN          人事行政總處/2024年行事曆/113年行事曆/過年7天年假
# 1      NaN      NaN        NaN  海葵颱風/颱風假/颱風路徑/最新颱風動態/颱風會來嗎/海葵颱風動向/停班停課
# 2      NaN  靚女學/靚女學  家庭關係/自我成長                      台大/孝順/頂嘴/資優生/父母/教育
# 3      NaN      NaN        NaN                     黃子佼/蔡燦得/買房/記帳/理財/退休
# 4      NaN      NaN        NaN              陳良基/憂鬱症/王素梅/陳良基 老婆/陳良基 憂鬱症
#
#      文章字數  上稿者 最後修改者        文章發布
# 0  1324.0  李易紓   李易紓  2023-06-20
# 1  3562.0  黃明惠   李易紓  2023-09-04
# 2  2485.0  洪慧如   郭美懿  2022-11-16
# 3  1151.0  洪慧如   李易紓  2023-06-20
# 4  2944.0  洪慧如   洪慧如  2023-12-05

# %% [markdown]
# ### 今周文章母分類、今周文章子分類，留下第一筆(最新)分類

# %%
## 把Null值改成Na
df_article['今周文章母分類'].replace(np.nan, "Na", inplace = True)
df_article['今周文章子分類'].replace(np.nan, "Na", inplace = True)

# %%
# 定義提取主分類的函數
def extract_article_category(category):
    return category.split('/')[0]

# 使用 apply 運用到整個 DataFrame
df_article['bt_main_categroy'] = df_article['今周文章母分類'].apply(extract_article_category)
df_article['bt_sub_categroy'] = df_article['今周文章子分類'].apply(extract_article_category)

# %%
df_article.head()
# Out:
#      article_id   PV_sum                                              文章標題  \
# 0  202305250031  1835894             明年過年放7天！2024年行事曆公布…3天以上連續假期有4個「開始排休囉」
# 1  202309020003   935926       全台停班停課一覽》海葵何時最接近、基北北桃放不放颱風假？哪天風雨最大？一圖看懂影響時程
# 2  202208240059   719167         台大法律系高材生頂撞賣臭豆腐的父母：阿母的沉默讓我羞愧「以為辯贏了，其實輸得徹底」
# 3  202306200007   636319    黃子佼當年最愛她》5歲出道、曾月刷20萬險變卡奴，30歲存千萬買房孝親！48歲蔡燦得的致富術
# 4  202312050037   609553  「太太輕生掛在16樓高空」前科技部長陳良基辭官退休，陪妻度過憂鬱症：結婚發誓照顧到老，說話要算數
#
#                 文章來源  文章屬性  名人專區           撰文 今周文章母分類 今周文章子分類 ESG文章母分類  \
# 0              數位部記者  政治社會   NaN        李易紓整理    產業時事    政治社會      NaN
# 1              數位部記者  生活消費   NaN       黃明惠 整理    職場生活    生活消費      NaN
# 2  外稿/書摘/廣編（無稿費不可轉載)  家庭教育  精選書摘          許峰源    職場生活    情感關係      NaN
# 3  外稿/書摘/廣編（無稿費不可轉載)  投資理財  各家之言  女人我最大 / 池宗玲    投資理財      理財      NaN
# 4  外稿/書摘/廣編（無稿費不可轉載)  職場學習  精選書摘    王素梅, 陳良基     職場生活    情感關係      NaN
#
#   ESG文章子分類  熟齡文章母分類    熟齡文章子分類                                   SEO分類  \
# 0      NaN      NaN        NaN          人事行政總處/2024年行事曆/113年行事曆/過年7天年假
# 1      NaN      NaN        NaN  海葵颱風/颱風假/颱風路徑/最新颱風動態/颱風會來嗎/海葵颱風動向/停班停課
# 2      NaN  靚女學/靚女學  家庭關係/自我成長                      台大/孝順/頂嘴/資優生/父母/教育
# 3      NaN      NaN        NaN                     黃子佼/蔡燦得/買房/記帳/理財/退休
# 4      NaN      NaN        NaN              陳良基/憂鬱症/王素梅/陳良基 老婆/陳良基 憂鬱症
#
#      文章字數  上稿者 最後修改者        文章發布 bt_main_categroy bt_sub_categroy
# 0  1324.0  李易紓   李易紓  2023-06-20             產業時事            政治社會
# 1  3562.0  黃明惠   李易紓  2023-09-04             職場生活            生活消費
# 2  2485.0  洪慧如   郭美懿  2022-11-16             職場生活            情感關係
# 3  1151.0  洪慧如   李易紓  2023-06-20             投資理財              理財
# 4  2944.0  洪慧如   洪慧如  2023-12-05             職場生活            情感關係

# %%
df_article_drop_columns = ['今周文章母分類', '今周文章子分類', 'ESG文章母分類', 'ESG文章子分類', '熟齡文章母分類', '熟齡文章子分類']

# %%
df_article.drop(df_article_drop_columns, axis = 1, inplace = True)

# %%
df_article.head()
# Out:
#      article_id   PV_sum                                              文章標題  \
# 0  202305250031  1835894             明年過年放7天！2024年行事曆公布…3天以上連續假期有4個「開始排休囉」
# 1  202309020003   935926       全台停班停課一覽》海葵何時最接近、基北北桃放不放颱風假？哪天風雨最大？一圖看懂影響時程
# 2  202208240059   719167         台大法律系高材生頂撞賣臭豆腐的父母：阿母的沉默讓我羞愧「以為辯贏了，其實輸得徹底」
# 3  202306200007   636319    黃子佼當年最愛她》5歲出道、曾月刷20萬險變卡奴，30歲存千萬買房孝親！48歲蔡燦得的致富術
# 4  202312050037   609553  「太太輕生掛在16樓高空」前科技部長陳良基辭官退休，陪妻度過憂鬱症：結婚發誓照顧到老，說話要算數
#
#                 文章來源  文章屬性  名人專區           撰文  \
# 0              數位部記者  政治社會   NaN        李易紓整理
# 1              數位部記者  生活消費   NaN       黃明惠 整理
# 2  外稿/書摘/廣編（無稿費不可轉載)  家庭教育  精選書摘          許峰源
# 3  外稿/書摘/廣編（無稿費不可轉載)  投資理財  各家之言  女人我最大 / 池宗玲
# 4  外稿/書摘/廣編（無稿費不可轉載)  職場學習  精選書摘    王素梅, 陳良基
#
#                                     SEO分類    文章字數  上稿者 最後修改者        文章發布  \
# 0          人事行政總處/2024年行事曆/113年行事曆/過年7天年假  1324.0  李易紓   李易紓  2023-06-20
# 1  海葵颱風/颱風假/颱風路徑/最新颱風動態/颱風會來嗎/海葵颱風動向/停班停課  3562.0  黃明惠   李易紓  2023-09-04
# 2                      台大/孝順/頂嘴/資優生/父母/教育  2485.0  洪慧如   郭美懿  2022-11-16
# 3                     黃子佼/蔡燦得/買房/記帳/理財/退休  1151.0  洪慧如   李易紓  2023-06-20
# 4              陳良基/憂鬱症/王素梅/陳良基 老婆/陳良基 憂鬱症  2944.0  洪慧如   洪慧如  2023-12-05
#
#   bt_main_categroy bt_sub_categroy
# 0             產業時事            政治社會
# 1             職場生活            生活消費
# 2             職場生活            情感關係
# 3             投資理財              理財
# 4             職場生活            情感關係

# %% [markdown]
# ## GA資料

# %%
ga_year = "2023"
ga_source_medium = ["google_organic", "FB_article", "LINE_super8", "LINE_text"]


ga_num = np.int(input("Please enter num of source and medium:"))
# Out:
# C:\Users\JoeJian\AppData\Local\Temp\ipykernel_14592\1301677501.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ga_num = np.int(input("Please enter num of source and medium:"))
# Please enter num of source and medium:3

# %%
df_ga = pd.read_csv(f"{ga_year}_{ga_source_medium[ga_num]}.csv", encoding = "unicode_escape")

df_ga_bk = df_ga.copy()

df_ga.head()
# Out:
#                                      Page path  Views
# 0            /bt_topic/2023/elderlyemployment/  38178
# 1  /article/category/183015/post/202305270002/  17429
# 2  /article/category/183027/post/202309180008/  16084
# 3  /article/category/183029/post/202101110016/  14325
# 4  /article/category/183027/post/202304120028/  12159

# %%
df_ga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29624 entries, 0 to 29623
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Page path  29623 non-null  object
#  1   Views      29624 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 463.0+ KB

# %%
df_ga[df_ga["Page path"].isna()]
# Out:
#       Page path  Views
# 10692       NaN     12

# %%
df_ga[df_ga["Views"].isna()]
# Out:
# Empty DataFrame
# Columns: [Page path, Views]
# Index: []

# %% [markdown]
# ### 去除空值

# %%
df_ga.dropna(inplace = True)

# %%
df_ga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29623 entries, 0 to 29623
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Page path  29623 non-null  object
#  1   Views      29623 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 694.3+ KB

# %% [markdown]
# ### 去除Views為0的值

# %%
views_zero = []

for index, path, views in df_ga.itertuples():
    # (index, Page path, Views, article_id)
    if views == 0:
        views_zero.append(index)

# %%
print(len(views_zero))
views_zero[:10]
# Out:
# 1207
# [28417, 28418, 28419, 28420, 28421, 28422, 28423, 28424, 28425, 28426]

# %%
print("調整前資料筆數:", len(df_ga))

df_ga.drop(views_zero, inplace = True)

print("調整後資料筆數:", len(df_ga))
# Out:
# 調整前資料筆數: 29623
# 調整後資料筆數: 28416

# %% [markdown]
# ### 檢查Page path資料

# %%
# 找到 URL 結尾不是 "/" 的資料
df_filtered = df_ga[~df_ga["Page path"].str.endswith("/")].reset_index(drop = True)

df_filtered
# Out:
#                                               Page path  Views
# 0                                               /mobile   6414
# 1                                                  /tag   5666
# 2                                         /subscription   4645
# 3                                                /login   2803
# 4                                       /catalog/183007   2363
# ...                                                 ...    ...
# 3642  /subscription_catalog/category/201856/post/202...      1
# 3643  /subscription_catalog/category/226631/post/202...      1
# 3644  /subscription_catalog/category/226631/post/202...      1
# 3645  /subscription_catalog/category/226631/post/202...      1
# 3646  /subscription_catalog/category/226631/post/202...      1
#
# [3647 rows x 2 columns]

# %%
## 檢查有沒有article開頭，但結尾不是"/"的資料

# 定義匹配模式的正則表達式
pattern_filter = r"/article/.*/post/(\d+)/"

for i in range(len(df_filtered)):

    match = re.match(pattern_filter, df_filtered["Page path"][i])
    if match:
        
        # 取得文章ID
        article_id = match.group(1)
        
        # 確保 article_id 是字符串型態 (str)
        article_id = str(article_id)
        print("文章ID:", article_id)
# Out:
# 文章ID: 202108310014
# 文章ID: 202109130003

# %% [markdown]
# ### 從 Page path中抓出文章id

# %%
# 定義匹配模式的正則表達式
pattern = r"/article/.*/post/(\d+)/"

# 定義一個函數，應用正則表達式並返回文章ID或 "Not Article"
def extract_article_id(url):
    match = re.match(pattern, url)

    if match and match.group(1):
        return np.int(match.group(1))
    
    else:
        return "0"

# %%
# 使用 apply 函數創建新的 'article_id' 欄位
df_ga['article_id'] = df_ga['Page path'].apply(extract_article_id)
# Out:
# C:\Users\JoeJian\AppData\Local\Temp\ipykernel_14592\967637069.py:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return np.int(match.group(1))

# %%
# 輸出結果
df_ga.head()
# Out:
#                                      Page path  Views    article_id
# 0            /bt_topic/2023/elderlyemployment/  38178             0
# 1  /article/category/183015/post/202305270002/  17429  202305270002
# 2  /article/category/183027/post/202309180008/  16084  202309180008
# 3  /article/category/183029/post/202101110016/  14325  202101110016
# 4  /article/category/183027/post/202304120028/  12159  202304120028

# %% [markdown]
# ### 去除article_id不符合資料的值

# %%
not_article_id = []

for index, path, views, article_id in df_ga.itertuples():
    # (index, Page path, Views, article_id)
    if article_id == "0":
        not_article_id.append(index)

# %%
print(len(not_article_id))
not_article_id[:10]
# Out:
# 4482
# [0, 70, 77, 119, 203, 550, 568, 600, 637, 707]

# %%
print("調整前資料筆數:", len(df_ga))

df_ga.drop(not_article_id, inplace = True)

print("調整後資料筆數:", len(df_ga))
# Out:
# 調整前資料筆數: 28416
# 調整後資料筆數: 23934

# %% [markdown]
# ### 合併重複article_id瀏覽量

# %%
df_ga['article_id'].value_counts() > 1
# Out:
# 202311230014     True
# 202310230039     True
# 202304030019     True
# 202211160003     True
# 202201300002     True
#                 ...
# 202312130085    False
# 202212210057    False
# 202111100066    False
# 202103230017    False
# 202101300007    False
# Name: article_id, Length: 23749, dtype: bool

# %%
column_names = ['article_id']

summeries = {'Views': 'sum'}

df_ga_sum = df_ga.groupby(by = column_names).agg(summeries)

df_ga_sum = df_ga_sum.sort_values("Views", ascending = False).reset_index()

# %% [markdown]
# ### Blend GA與後台資料

# %%
df_data_all = pd.merge(df_ga_sum, df_article, how = 'inner')
# print(df_all_sum)

print(len(df_data_all))

df_data_all.head()
# Out:
# 19293
#      article_id  Views  PV_sum  \
# 0  202305270002  17429  149360
# 1  202309180008  16085   44179
# 2  202101110016  14326   40803
# 3  202304120028  12159  105878
# 4  202301030018  11756   65908
#
#                                               文章標題               文章來源  文章屬性  \
# 0  黃仁勳台大演說全文！分享輝達3個「失敗與成功」分岔點：為覓食而奔跑，或為逃離被當成食物而奔跑！              數位部記者  產業動態
# 1     被感染的人越來越多！小心3病毒正流行...醫憂無止盡：每種病毒還會1次、2次、3次一直得              數位部記者  政治社會
# 2    寒流低溫60小時已猝死38人⋯為何意外都在床上、浴室旁、房間內？重症醫揭室內安全溫度能保命  外稿/書摘/廣編（無稿費不可轉載)  幸福熟齡
# 3      62歲淡大前副校長墜樓離世，上週才上節目毫無異狀…遺書寫下「腦部病變智能已失」無法教學              數位部記者  政治社會
# 4        全民「開工紅包」金額出爐！蔡英文宣布1800億扣開支「給現金」…何時發、怎麼領曝光              數位部記者  政治社會
#
#    名人專區            撰文                                    SEO分類    文章字數  上稿者  \
# 0   NaN         李易紓整理        黃仁勳台大/黃仁勳/黃仁勳輝達/黃仁勳身價/黃仁勳演講/黃仁勳夜市  2588.0  李易紓
# 1   NaN         林依榕整理        腸胃炎吃什麼/腸胃炎症狀/B型流感症狀/B型流感多久會好/A型流感  2332.0  林依榕
# 2  黃軒醫師  黃軒/胸腔暨重症專科醫師                猝死/寒流/保暖/黃軒/失溫/天冷猝死/天氣/溫度  2959.0  李易紓
# 3   NaN           李易紓  王高成/淡江大學/淡大前副校長/淡江大學前副校長墜樓/墜樓意外/淡江大學副校長  1041.0  李易紓
# 4   NaN        胡肇芳 整理      還稅於民/現金/稅收超徵/1800億/蘇貞昌/蔡英文/發現金/普發現金  1827.0   肇芳
#
#   最後修改者        文章發布 bt_main_categroy bt_sub_categroy
# 0   李易紓  2023-05-29             產業時事              科技
# 1   李易紓  2023-09-18             產業時事            政治社會
# 2   李易紓  2023-01-28             職場生活              健康
# 3   李易紓  2023-04-12             產業時事            政治社會
# 4    肇芳  2023-01-04             產業時事            政治社會

# %%
df_data_all.describe()
# Out:
#          article_id         Views        PV_sum          文章字數
# count  1.929300e+04  19293.000000  1.929300e+04  19291.000000
# mean   2.021653e+11    388.310009  1.052200e+04   1737.321342
# std    2.700335e+08    930.334533  3.079590e+04   1070.963613
# min    1.998111e+11      1.000000  3.600000e+01      5.000000
# 25%    2.021102e+11      3.000000  5.480000e+02    987.000000
# 50%    2.023012e+11     14.000000  2.146000e+03   1515.000000
# 75%    2.023071e+11    348.000000  8.329000e+03   2166.000000
# max    2.023123e+11  17429.000000  1.835894e+06  21178.000000

# %%
df_data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19293 entries, 0 to 19292
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   article_id        19293 non-null  int64
#  1   Views             19293 non-null  int64
#  2   PV_sum            19293 non-null  int64
#  3   文章標題              19293 non-null  object
#  4   文章來源              18979 non-null  object
#  5   文章屬性              18534 non-null  object
#  6   名人專區              5399 non-null   object
#  7   撰文                19291 non-null  object
#  8   SEO分類             18547 non-null  object
#  9   文章字數              19291 non-null  float64
#  10  上稿者               15946 non-null  object
#  11  最後修改者             19143 non-null  object
#  12  文章發布              19293 non-null  object
#  13  bt_main_categroy  19293 non-null  object
#  14  bt_sub_categroy   19293 non-null  object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 2.4+ MB

# %% [markdown]
# #### 文章字數為NaN的資料，該篇只有圖片
# #### fillna with 0

# %%
df_data_all[df_data_all["文章字數"].isna()]
# Out:
#          article_id  Views  PV_sum  \
# 13695  202210190027      4     109
# 18392  202305030055      1     109
#
#                                                   文章標題      文章來源  文章屬性 名人專區  \
# 13695  圖解禁令〉飛彈、無人機  都靠這些晶片、記憶體          一張圖看懂美國絕殺令終極目標  今周/特刊/叢書  產業動態  NaN
# 18392                             調查說明》 中港台企業  市值排行這樣算  今周/特刊/叢書  產業動態  NaN
#
#         撰文                      SEO分類  文章字數  上稿者 最後修改者        文章發布  \
# 13695  侯良儒        晶片/記憶體/量子運算/超級電腦/美國   NaN  楊佩珍   李易紓  2022-10-19
# 18392  黃伃彤  市值排行/兩岸三地/資本市場/新儲能市場/家電市場   NaN  楊佩珍   楊佩珍  2023-05-03
#
#       bt_main_categroy bt_sub_categroy
# 13695             產業時事              科技
# 18392             投資理財              理財

# %%
df_data_all["文章字數"].fillna(0, inplace = True)

# %% [markdown]
# #### article_id前8碼為文章發實際日期
# #### 改成datetime，欄位名稱調整為"article_date"

# %%
df_data_all["article_id"] = df_data_all["article_id"].astype(np.str)
# Out:
# C:\Users\JoeJian\AppData\Local\Temp\ipykernel_14592\1519977408.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_data_all["article_id"] = df_data_all["article_id"].astype(np.str)

# %%
df_data_all["article_date"] = df_data_all["article_id"].apply(lambda X: X[:8])

# colname_article_date = {"文章發布": "article_date"}
# df_data_all.rename(columns = colname_article_date, inplace = True)

# %%
df_data_all["article_date"] = pd.to_datetime(df_data_all["article_date"])

# %%
df_data_all["article_date"].head()
# Out:
# 0   2023-05-27
# 1   2023-09-18
# 2   2021-01-11
# 3   2023-04-12
# 4   2023-01-03
# Name: article_date, dtype: datetime64[ns]

# %% [markdown]
# #### Note: 可以由article_id -> article_date來比較熱門的新文章以及熱門的舊文章

# %%
df_data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19293 entries, 0 to 19292
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   article_id        19293 non-null  object
#  1   Views             19293 non-null  int64
#  2   PV_sum            19293 non-null  int64
#  3   文章標題              19293 non-null  object
#  4   文章來源              18979 non-null  object
#  5   文章屬性              18534 non-null  object
#  6   名人專區              5399 non-null   object
#  7   撰文                19291 non-null  object
#  8   SEO分類             18547 non-null  object
#  9   文章字數              19293 non-null  float64
#  10  上稿者               15946 non-null  object
#  11  最後修改者             19143 non-null  object
#  12  文章發布              19293 non-null  object
#  13  bt_main_categroy  19293 non-null  object
#  14  bt_sub_categroy   19293 non-null  object
#  15  article_date      19293 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(12)
# memory usage: 2.5+ MB

# %% [markdown]
# ### 匯出前100名文章資料

# %%
df_data_all.head(100).to_csv(f"./data/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_all.csv", encoding = "utf-8-sig", index = False)

# %% [markdown]
# # 2. EDA

# %%
## 定義中文字體
my_font_type = ["Microsoft YaHei"]  # 'Microsoft YaHei': 微軟雅黑體

plt.style.use("fivethirtyeight")

## 可以看出有哪些可以使用的主題
# plt.style.available

# %% [markdown]
# ## 2-1 文章屬性

# %% [markdown]
# ### 1. 篇數

# %%
## 如果要顯示資料標籤，才須加下面程式碼

# ## 對類別做計數
# from collections import Counter

# ## 用Counter對類別做加總
# no_nan_data = df_data_all['文章屬性'].dropna()


# attribution_counts = Counter(no_nan_data)
# attribution_counts

# ## 依照篇數做排序

# attr_values, attr_counts = zip(*sorted(attribution_counts.items(), key = lambda x: x[1], reverse= True))
# attr_values, attr_counts


## --- 以下加在plt的區塊中 ---

# ## 顯示資料標籤
# for i, count in enumerate(attr_counts):
#     plt.text(attr_values[i], count + 0.1, str(count), ha='center', va='bottom')

# ## ha='center' 表示居中對齊
# ## va='bottom' 表示文本垂直方向上對齊底部

# %%
article_attr_counts = df_data_all["文章屬性"].value_counts()

# %%
article_attr_counts.to_csv(f"./data/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_article_attr_counts.csv", encoding = "utf-8-sig")

# %%
plt.figure(figsize = (16,9))

plt.bar(x = article_attr_counts.index,
        height = article_attr_counts.values,
        color = "green")

plt.rcParams["font.sans-serif"] = my_font_type

plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)

plt.title(f"{ga_year}年度 {ga_source_medium[ga_num]} 文章屬性(篇數)", pad = 20, fontsize = 20, fontweight = "bold", fontname = my_font_type)


plt.savefig(f"./image/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_article_attr_counts.png")
plt.show()

# %%
article_attr_views = df_data_all.groupby("文章屬性").sum().Views.sort_values(ascending = False)
# Out:
# C:\Users\JoeJian\AppData\Local\Temp\ipykernel_14592\3788926252.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   article_attr_views = df_data_all.groupby("文章屬性").sum().Views.sort_values(ascending = False)

# %%
article_attr_views.to_csv(f"./data/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_article_attr_view.csv", encoding = "utf-8-sig")

# %%
plt.figure(figsize = (16,9))

plt.bar(x = article_attr_views.index,
        height = (article_attr_views.values / 10000),
        color = "green")

plt.rcParams["font.sans-serif"] = my_font_type

plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)

plt.title(f"{ga_year}年度 {ga_source_medium[ga_num]} 文章屬性(瀏覽量，單位:萬)", pad = 20, fontsize = 20, fontweight = "bold", fontname = my_font_type)

plt.savefig(f"./image/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_article_attr_views.png")
plt.show()

# %% [markdown]
# ## 2-2 新文章、舊文章篇數及流量占比

# %% [markdown]
# ### 使用 ["article_date"].dt.year 做區分

# %%
plt.figure(figsize = (16, 9))

df_data_all["article_date"].dt.year.value_counts().sort_index(ascending = False).plot(kind = "bar", color = "green")

plt.xticks(rotation = 45, fontsize = 15)
plt.yticks(fontsize = 15)

plt.title(f"{ga_year}年度 {ga_source_medium[ga_num]} 歷年文章量", pad = 20, fontsize = 20, fontweight = "bold", fontname = my_font_type)

plt.savefig(f"./image/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_article_years_counts.png")
plt.show()

# %%
df_data_all["article_year"] = df_data_all["article_date"].dt.year

# %%
plt.figure(figsize = (16, 9))

df_data_all.groupby(by = "article_year")["Views"].sum().sort_index(ascending = False).plot(kind = "bar", color = "green")

plt.xticks(rotation = 45, fontsize = 15)
plt.yticks(fontsize = 15)

plt.title(f"{ga_year}年度 {ga_source_medium[ga_num]} 歷年文章瀏覽量", pad = 20, fontsize = 20, fontweight = "bold", fontname = my_font_type)

plt.savefig(f"./image/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_article_years_views.png")
plt.show()

# %% [markdown]
# ### 該年度文章：df_new_article

# %%
df_new_article = df_data_all[df_data_all["article_date"].dt.year == 2023]
df_new_article.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10253 entries, 0 to 19279
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   article_id        10253 non-null  object
#  1   Views             10253 non-null  int64
#  2   PV_sum            10253 non-null  int64
#  3   文章標題              10253 non-null  object
#  4   文章來源              10253 non-null  object
#  5   文章屬性              10253 non-null  object
#  6   名人專區              2131 non-null   object
#  7   撰文                10253 non-null  object
#  8   SEO分類             10009 non-null  object
#  9   文章字數              10253 non-null  float64
#  10  上稿者               10253 non-null  object
#  11  最後修改者             10253 non-null  object
#  12  文章發布              10253 non-null  object
#  13  bt_main_categroy  10253 non-null  object
#  14  bt_sub_categroy   10253 non-null  object
#  15  article_date      10253 non-null  datetime64[ns]
#  16  article_year      10253 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(12)
# memory usage: 1.4+ MB

# %%
df_new_article[["文章標題", "文章屬性"]].head(10)
# Out:
#                                                  文章標題  文章屬性
# 0     黃仁勳台大演說全文！分享輝達3個「失敗與成功」分岔點：為覓食而奔跑，或為逃離被當成食物而奔跑！  產業動態
# 1        被感染的人越來越多！小心3病毒正流行...醫憂無止盡：每種病毒還會1次、2次、3次一直得  政治社會
# 3         62歲淡大前副校長墜樓離世，上週才上節目毫無異狀…遺書寫下「腦部病變智能已失」無法教學  政治社會
# 4           全民「開工紅包」金額出爐！蔡英文宣布1800億扣開支「給現金」…何時發、怎麼領曝光  政治社會
# 5   房貸補貼來了，一次每戶發3萬！央行連升息快把購屋族壓垮...符合2要件、家戶所得低於「這門檻...   房地產
# 6         蘇貞昌拍板普發現金6000元！這群人「加碼給錢」…我要給帳戶嗎？何時能拿到？一文搞清楚  政治社會
# 7                輸入2組號碼人人就能領6000元！政府普發現金這12家銀行ATM都可領！  政治社會
# 8               500元青春動滋券6/1開領，165萬人專屬！幾歲才能申請？官網在哪一次看  政治社會
# 9      不斷更新／杜蘇芮直逼「強烈颱風」最快14:30發陸警！風雨最劇時間點出爐…這2區颱風假機率高  生活消費
# 10      萬安演習一連4天！外送「這時段」沒得叫、搭公車有影響？各縣市時間、管制一文看，違者罰15萬  政治社會

# %%
df_new_article.to_csv(f"./data/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_new_article.csv", encoding = "utf-8-sig")

# %%
new_article_attr_counts = df_new_article["文章屬性"].value_counts()

# %%
new_article_attr_counts.to_csv(f"./data/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_new_article_attr_counts.csv", encoding = "utf-8-sig")

# %%
plt.figure(figsize = (16, 9))

plt.bar(x = new_article_attr_counts.index,
        height = new_article_attr_counts.values,
        color = "green")

plt.rcParams["font.sans-serif"] = my_font_type

plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)

plt.title("該年度文章篇數", pad = 20, fontsize = 20, fontweight = "bold", fontname = my_font_type)

plt.savefig(f"./image/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_new_article_attr_counts.png")
plt.show()

# %%
new_article_attr_views = df_new_article.groupby("文章屬性").sum().Views.sort_values(ascending = False)
# Out:
# C:\Users\JoeJian\AppData\Local\Temp\ipykernel_14592\67163466.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_article_attr_views = df_new_article.groupby("文章屬性").sum().Views.sort_values(ascending = False)

# %%
new_article_attr_views.to_csv(f"./data/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_new_article_attr_views.csv", encoding = "utf-8-sig")

# %%
plt.figure(figsize = (16, 9))

plt.bar(x = new_article_attr_views.index,
        height = (new_article_attr_views.values / 10000),
        color = "green")

plt.rcParams["font.sans-serif"] = my_font_type

plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)

plt.title("該年度文章瀏覽量(單位:萬)", pad = 20, fontsize = 20, fontweight = "bold", fontname = my_font_type)

plt.savefig(f"./image/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_new_article_attr_views.png")
plt.show()

# %% [markdown]
# ### 舊文：df_old_article

# %%
df_old_article = df_data_all[df_data_all["article_date"].dt.year != 2023]
df_old_article.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9040 entries, 2 to 19292
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   article_id        9040 non-null   object
#  1   Views             9040 non-null   int64
#  2   PV_sum            9040 non-null   int64
#  3   文章標題              9040 non-null   object
#  4   文章來源              8726 non-null   object
#  5   文章屬性              8281 non-null   object
#  6   名人專區              3268 non-null   object
#  7   撰文                9038 non-null   object
#  8   SEO分類             8538 non-null   object
#  9   文章字數              9040 non-null   float64
#  10  上稿者               5693 non-null   object
#  11  最後修改者             8890 non-null   object
#  12  文章發布              9040 non-null   object
#  13  bt_main_categroy  9040 non-null   object
#  14  bt_sub_categroy   9040 non-null   object
#  15  article_date      9040 non-null   datetime64[ns]
#  16  article_year      9040 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(12)
# memory usage: 1.2+ MB

# %%
df_old_article[["文章標題", "文章屬性"]].head(10)
# Out:
#                                                  文章標題  文章屬性
# 2       寒流低溫60小時已猝死38人⋯為何意外都在床上、浴室旁、房間內？重症醫揭室內安全溫度能保命  幸福熟齡
# 27      龍巖創辦人李世聰腦瘤病逝，享壽65歲...昔談殯儀館讓人怵目驚心：「我要當殯葬業的台積電」  職場學習
# 80          飽經歲月的容顏 成刻刀下盛開風景與　媽媽的奮鬥靈魂同在 朱銘寶刀未老，木刻「浮生」  職場學習
# 200        李世聰身家數百億，腦瘤纏身3年…醫師：頭痛、走不穩、視力模糊，12警訊中年後特別注意  幸福熟齡
# 247   我被封鎖了嗎？LINE沒出現「這符號」哭哭了...別把對話窗當記事本！少做1動作，還是會被看光  生活消費
# 291             「爬山」是一帖良藥！罹癌後存活45年...台大醫師從坐輪椅到登上玉山的奇蹟  健康休閒
# 296       香客大樓卻有星級酒店規格獨立筒床墊、羽絨枕被？全台2間CP值爆表香客大樓，住宿費0元起  健康休閒
# 298  高虹安涉貪46萬助理費遭起訴！貪汙罪、偽造文書...一審若有罪還能當市長？男友閃過不起訴原因曝光  政治社會
# 321  3000元節能家電補助2/1起跑，700萬台冷氣冰箱等著換！線上怎麼申請、要準備啥？3步驟一次看  生活消費
# 354           比加工食品還毒！「超加工食品」吃多恐損害腦細胞，讓人變笨、致癌…這些食物碰不得  健康休閒

# %%
df_old_article.to_csv(f"./data/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_old_article.csv", encoding = "utf-8-sig")

# %%
old_article_attr_counts = df_old_article["文章屬性"].value_counts()

# %%
old_article_attr_counts.to_csv(f"./data/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_old_article_attr_counts.csv", encoding = "utf-8-sig")

# %%
plt.figure(figsize = (16, 9))

plt.bar(x = old_article_attr_counts.index,
        height = old_article_attr_counts.values,
        color = "green")

plt.rcParams["font.sans-serif"] = my_font_type

plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)

plt.title("舊年度文章篇數", pad = 20, fontsize = 20, fontweight = "bold", fontname = my_font_type)

plt.savefig(f"./image/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_old_article_attr_counts.png")
plt.show()

# %%
old_article_attr_views = df_old_article.groupby("文章屬性").sum().Views.sort_values(ascending = False)
# Out:
# C:\Users\JoeJian\AppData\Local\Temp\ipykernel_14592\1970446934.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   old_article_attr_views = df_old_article.groupby("文章屬性").sum().Views.sort_values(ascending = False)

# %%
old_article_attr_views.to_csv(f"./data/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_old_article_attr_views.csv", encoding = "utf-8-sig")

# %%
plt.figure(figsize = (16, 9))

plt.bar(x = old_article_attr_views.index,
        height = (old_article_attr_views.values / 10000),
        color = "green")

plt.rcParams["font.sans-serif"] = my_font_type

plt.xticks(rotation = 45, fontsize = 12)
plt.yticks(fontsize = 12)

plt.title("舊年度文章瀏覽量(單位:萬)", pad = 20, fontsize = 20, fontweight = "bold", fontname = my_font_type)

plt.savefig(f"./image/{ga_year}/{ga_source_medium[ga_num]}/{ga_year}_{ga_source_medium[ga_num]}_old_article_attr_views.png")
plt.show()

# %% [markdown]
# ## 2-3 該年度每月文章比例

# %% [markdown]
# ### 使用article_date.dt.month來看該月份文章比例有多少

# %%
df_new_article["article_month"] = df_new_article["article_date"].dt.month
# Out:
# C:\Users\JoeJian\AppData\Local\Temp\ipykernel_14592\1928150024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new_article["article_month"] = df_new_article["article_date"].dt.month

# %%
list_article_attr = df_new_article["文章屬性"].unique()

# %%
df_month_views = df_new_article.groupby(by = ["article_month", "文章屬性"])["Views"].sum()

# %%
for i in range(len(list_article_attr)):
    plt.figure(figsize = (16, 9))
    
    df_month_views.loc[:, list_article_attr[i]].plot(kind = "bar", color = "green")
    plt.title(f"{ga_year}年度 {ga_source_medium[ga_num]} {list_article_attr[i]} 每月流量", pad = 20, fontsize = 20, fontweight = "bold", fontname = my_font_type)
    
    plt.xticks(rotation = 0, fontsize = 12)
    plt.yticks(fontsize = 12)
    
    plt.savefig(f"./image/{ga_year}/{ga_source_medium[ga_num]}/month/{ga_year}_{ga_source_medium[ga_num]}_{list_article_attr[i]}_month_attr_views.png")
    plt.show()

# %% [markdown]
# # 3. 語意分析
