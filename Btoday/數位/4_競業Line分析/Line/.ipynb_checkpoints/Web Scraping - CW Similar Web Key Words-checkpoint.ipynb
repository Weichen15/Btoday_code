# %% [markdown]
# # 1. Import Modules

# %%
from selenium import webdriver
import time
import os
import pandas as pd

import numpy as np
import datetime
import re

# %% [markdown]
# # 2. Read Data

# %%
file_date = input("請輸入資料區間： ")
# Out:
# 請輸入資料區間： 20231128_20231129

# %%
## 匯入web資料
"""
content_id
content_title_h1
content_title_description
content_class_main
content_class_sub
content_date_time
content_tag
"""

df_cw_file = pd.read_csv(f'CW_LINE_{file_date}.csv')

df_cw_file.head()
# Out:
#                                                  URL
# 0  https://www.cw.com.tw/article/5128230?utm_camp...
# 1  https://www.cw.com.tw/article/5128166?utm_sour...
# 2  https://www.cw.com.tw/article/5128165?utm_sour...
# 3  https://www.cw.com.tw/article/5128172?utm_sour...
# 4  https://www.cw.com.tw/article/5128174?utm_sour...

# %%
# web 之後動態調整，讀取欲抓取網站的url

url_number = 0
today_date = datetime.date.today()
df_cw_sw_all = pd.DataFrame()
wrong_post_id = [] # 這邊不會用到

for URL in df_cw_file['URL']:
    
    web = URL

    print(web)
    try:

        # --- Begin 抓取文章id ---

        content_id = web.split("/")[-1]
#         content_id = content_id.split("?")[0]
        print(content_id)

        # --- End 抓取文章id ---

        path = "C:/Users/JoeJian/OneDrive - Business Today Magazine/桌面/Python Codes/Web_Scraping_in_Python_BeautifulSoup_Selenium&Scrapy_2023/ChromeDriver/chromedriver"

        driver = webdriver.Chrome(path)

        driver.get(web)

        driver.maximize_window()


        content_all_drive = driver.find_element_by_xpath(f"//article[@data-link='{content_id}']")

        # --- Begin 大標題 ---

        lst_title_h1 = []

        content_title_h1 = content_all_drive.find_element_by_xpath("./div/div/h1").text

        print('title: ', content_title_h1)

        lst_title_h1.append(content_title_h1)

        # --- End 大標題 ---
        
        # --- Begin 描述 ---

        lst_title_description = []

        title_description = driver.find_element_by_xpath("//meta[@name='description']").get_attribute("content")
        print('title description: ', title_description)
        lst_title_description.append(title_description)

        # --- End 前言 ---

        # --- Begin 文章分類及文章發佈日 ---

        lst_content_class_main = []
        lst_content_class_sub = []
        lst_content_date = []

        content_class_main = driver.find_element_by_xpath("(//ul[@class='breadcrumb list-reset']/li)[1]").text
        content_class_sub = driver.find_element_by_xpath("(//ul[@class='breadcrumb list-reset']/li)[2]").text

        print("Main class: ",content_class_main)
        lst_content_class_main.append(content_class_main)
        print("Sub class: ", content_class_sub)
        lst_content_class_sub.append(content_class_sub)

        # 文章發布時間

        content_date_time = driver.find_element_by_tag_name("time").text

        content_date_time = content_date_time[-10:]

        print("文章發布日： ", content_date_time)

        lst_content_date.append(content_date_time)

        # --- End 文章分類及文章發佈日 ---


        # --- Begin 標籤 ---

        lst_content_tag = []

        content_tag = content_all_drive.find_element_by_class_name("article__keyword").text

        lst_content_tag = content_tag.replace("#","").split("\n")

        print("Tag: ", lst_content_tag)

        # --- End 標籤 ---

        driver.quit()

        # List 轉 Series
        series_id = pd.Series(content_id)
        series_title_h1 = pd.Series(lst_title_h1)
        series_title_description = pd.Series(lst_title_description)
        series_content_class_main = pd.Series(lst_content_class_main)
        series_content_class_sub = pd.Series(lst_content_class_sub)
        series_content_date = pd.Series(lst_content_date)

        lst_content_tag = ",".join(lst_content_tag) # 把list中的資料用","join起來
        series_content_tag = pd.Series(lst_content_tag)

        bt_column_name = ['content_id'
                         ,'content_title_h1'
                         ,'content_title_description'
                         ,'content_class_main'
                         ,'content_class_sub'
                         ,'content_date_time'
                         ,'content_tag']

        # Series 放到 DataFrame
        df_cw_sw_keyword = pd.concat([series_id
                                     ,series_title_h1
                                     ,series_title_description
                                     ,series_content_class_main
                                     ,series_content_class_sub
                                     ,series_content_date
                                     ,series_content_tag]
                                     ,axis = 1)

        df_cw_sw_keyword.columns = bt_column_name

        url_number += 1

        df_cw_sw_all = pd.concat([df_cw_sw_all, df_cw_sw_keyword], ignore_index=True)
    
    except:
        
        driver.quit()
        
        print("Manul:", web)
        
        wrong_post_id.append(web)
        print("wrong_post_id", wrong_post_id)
        
        series_id = pd.Series(wrong_post_id)
        
        df_cw_sw_keyword_except = pd.concat([series_id], axis = 1)
        
        df_cw_sw_keyword_except.columns = ["content_id"]
        df_cw_sw_all = pd.concat([df_cw_sw_all, df_cw_sw_keyword_except], ignore_index=True)
        
        url_number += 1
    
print("----------------- Finish -------------------")

df_cw_sw_all.to_csv(f'{file_date}_CommonWealth_LINE.csv', index = False, encoding = 'UTF-8-sig')
# Out:
# https://www.cw.com.tw/article/5128230?utm_campaign=line_cw-social-daily-231128-5128230&utm_source=line_cw&utm_medium=social
# 5128230?utm_campaign=line_cw-social-daily-231128-5128230&utm_source=line_cw&utm_medium=social
# title:  債市買點到了嗎？給債券ETF套牢族的3種方案
# title description:  聯準會一直不鬆口停止升息，讓包括70萬債券ETF投資人，幾全數買在高點。11月債市出現反轉，空手投資人的買點到了嗎？套在高點的投資人該加碼攤平嗎？
# Main class:  財經
# Sub class:  投資理財
# 文章發布日：  2023-11-27
# Tag:  ['債市', '美債', 'ETF', '升息', '聯準會', '投資', '利率']
# https://www.cw.com.tw/article/5128166?utm_source=line_cw&utm_medium=social&utm_campaign=line_cw-social-daily-231128-5128166
# 5128166?utm_source=line_cw&utm_medium=social&utm_campaign=line_cw-social-daily-231128-5128166
# title:  世界「多極失序」、經濟不穩定性提高　《經濟學人》2024年度特刊，預告全球十大趨勢
# title description:  【2024全球大趨勢｜編者的話】2024最需要關心的十件事有哪些？《天下雜誌》連續多年取得英國權威媒體《經濟學人》（The Economist）年度重量級刊物《The World Ahead 2024》中文版獨家授權《2024全球大趨勢》，為您獨家解讀2024世界大勢。
# Main class:  重磅外媒
# Sub class:  經濟學人
# 文章發布日：  2023-11-23
# Tag:  ['2024全球大趨勢', '美國大選', '通膨', 'AI', '新冷戰', '以巴衝突', '烏俄戰爭']
# https://www.cw.com.tw/article/5128165?utm_source=line_cw&utm_medium=social&utm_campaign=line_cw-social-daily-231128-5128165
# 5128165?utm_source=line_cw&utm_medium=social&utm_campaign=line_cw-social-daily-231128-5128165
# title description:  台灣一年詐欺財損近1%GDP，稱霸已開發國家。臉書、簡訊「加賴領飆股」廣告，背後是科技升級的犯罪新模式。白領共犯自稱只是賺外快，但當他們開著百萬名車，我們不只失去財富，更面臨社會價值崩毀危機。
# Main class:  政治社會
# Sub class:  社會現場
# 文章發布日：  2023-11-28
# Tag:  ['詐騙']
# ----------------- Finish -------------------

# %%
df_cw_sw_all
# Out:
#                                           content_id  \
# 0  5128230?utm_campaign=line_cw-social-daily-2311...
# 1  5128166?utm_source=line_cw&utm_medium=social&u...
# 2  5128165?utm_source=line_cw&utm_medium=social&u...
# 3  5128172?utm_source=line_cw&utm_medium=social&u...
# 4  5128174?utm_source=line_cw&utm_medium=social&u...
# 5  5128166?utm_source=line_cw&utm_medium=social&u...
# 6  5128235?utm_campaign=line_cw-social-daily-2311...
#
#                             content_title_h1  \
# 0                     債市買點到了嗎？給債券ETF套牢族的3種方案
# 1  世界「多極失序」、經濟不穩定性提高　《經濟學人》2024年度特刊，預告全球十大趨勢
# 2     2024全世界最重要的兩場選舉，一場在台灣？《經濟學人》總編輯：民主岌岌可危
# 3      2024全球經濟軟著陸？經濟學人年度特刊《2024全球大趨勢》：別指望了！
# 4   員工不想用AI怎麼辦？經濟學人年度特刊《2024全球大趨勢》企業用不用AI的難題
# 5  世界「多極失序」、經濟不穩定性提高　《經濟學人》2024年度特刊，預告全球十大趨勢
# 6            「做詐騙跟一般接案沒兩樣」　圖解：工程師、銀行員的「百萬斜槓」
#
#                            content_title_description content_class_main  \
# 0  聯準會一直不鬆口停止升息，讓包括70萬債券ETF投資人，幾全數買在高點。11月債市出現反轉，...                 財經
# 1  【2024全球大趨勢｜編者的話】2024最需要關心的十件事有哪些？《天下雜誌》連續多年取得英...               重磅外媒
# 2  【2024全球大趨勢｜評論】從美國到印度到台灣，2024年有超過70個國家舉行大選，自由民主...               重磅外媒
# 3           【2024全球大趨勢｜評論】雖然通膨正在降溫，但2024年的全球經濟仍相當脆弱。               重磅外媒
# 4  【2024全球大趨勢｜評論】生成式AI能為企業帶來很多潛在好處，但別指望它會一夜之間被採用。...               重磅外媒
# 5  【2024全球大趨勢｜編者的話】2024最需要關心的十件事有哪些？《天下雜誌》連續多年取得英...               重磅外媒
# 6  台灣一年詐欺財損近1%GDP，稱霸已開發國家。臉書、簡訊「加賴領飆股」廣告，背後是科技升級的...               政治社會
#
#   content_class_sub content_date_time                         content_tag
# 0              投資理財        2023-11-27              債市,美債,ETF,升息,聯準會,投資,利率
# 1              經濟學人        2023-11-23  2024全球大趨勢,美國大選,通膨,AI,新冷戰,以巴衝突,烏俄戰爭
# 2              經濟學人        2023-11-23          2024全球大趨勢,選舉,總統大選,美國,台灣,民主
# 3              經濟學人        2023-11-23            2024全球大趨勢,通膨,升息,全球經濟,軟著陸
# 4              經濟學人        2023-11-23     2024全球大趨勢,AI,人工智慧,ChatGPT,生成式AI
# 5              經濟學人        2023-11-23  2024全球大趨勢,美國大選,通膨,AI,新冷戰,以巴衝突,烏俄戰爭
# 6              社會現場        2023-11-28                                  詐騙
